# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv")

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
Dataset = data[["car_ID", "CarName", "price", "fueltype", "carbody", "carlength", "carwidth", "carheight",
                "curbweight", "doornumber", "enginelocation", "enginesize", "horsepower", "stroke", "boreratio",
                "fuelsystem", "wheelbase", "peakrpm", "citympg", "highwaympg", "symboling", "drivewheel",
                "compressionratio", "aspiration"]]

# %%
Dataset
# Out:
#      car_ID                   CarName    price fueltype      carbody  \
# 0         1        alfa-romero giulia  13495.0      gas  convertible
# 1         2       alfa-romero stelvio  16500.0      gas  convertible
# 2         3  alfa-romero Quadrifoglio  16500.0      gas    hatchback
# 3         4               audi 100 ls  13950.0      gas        sedan
# 4         5                audi 100ls  17450.0      gas        sedan
# ..      ...                       ...      ...      ...          ...
# 200     201           volvo 145e (sw)  16845.0      gas        sedan
# 201     202               volvo 144ea  19045.0      gas        sedan
# 202     203               volvo 244dl  21485.0      gas        sedan
# 203     204                 volvo 246  22470.0   diesel        sedan
# 204     205               volvo 264gl  22625.0      gas        sedan
#
#      carlength  carwidth  carheight  curbweight doornumber  ... boreratio  \
# ...

# %%
Dataset.shape
# Out:
# (205, 24)

# %%
Dataset.isnull().sum()
# Out:
# car_ID              0
# CarName             0
# price               0
# fueltype            0
# carbody             0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# doornumber          0
# enginelocation      0
# enginesize          0
# horsepower          0
# stroke              0
# boreratio           0
# fuelsystem          0
# wheelbase           0
# peakrpm             0
# citympg             0
# highwaympg          0
# symboling           0
# drivewheel          0
# compressionratio    0
# aspiration          0
# dtype: int64

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   CarName           205 non-null    object
#  2   price             205 non-null    float64
#  3   fueltype          205 non-null    object
#  4   carbody           205 non-null    object
#  5   carlength         205 non-null    float64
#  6   carwidth          205 non-null    float64
#  7   carheight         205 non-null    float64
#  8   curbweight        205 non-null    int64
#  9   doornumber        205 non-null    object
#  10  enginelocation    205 non-null    object
#  11  enginesize        205 non-null    int64
#  12  horsepower        205 non-null    int64
#  13  stroke            205 non-null    float64
#  14  boreratio         205 non-null    float64
#  15  fuelsystem        205 non-null    object
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
Dataset.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,8))
sns.displot(Dataset.price)
plt.show()

# %%
print(Dataset.corr())
# Out:
#                     car_ID     price  carlength  carwidth  carheight  \
# car_ID            1.000000 -0.109093   0.170636  0.052387   0.255960
# price            -0.109093  1.000000   0.682920  0.759325   0.119336
# carlength         0.170636  0.682920   1.000000  0.841118   0.491029
# carwidth          0.052387  0.759325   0.841118  1.000000   0.279210
# carheight         0.255960  0.119336   0.491029  0.279210   1.000000
# curbweight        0.071962  0.835305   0.877728  0.867032   0.295572
# enginesize       -0.033930  0.874145   0.683360  0.735433   0.067149
# horsepower       -0.015006  0.808139   0.552623  0.640732  -0.108802
# stroke           -0.160824  0.079443   0.129533  0.182942  -0.055307
# boreratio         0.260064  0.553173   0.606454  0.559150   0.171071
# wheelbase         0.129729  0.577816   0.874587  0.795144   0.589435
# peakrpm          -0.203789 -0.085267  -0.287242 -0.220012  -0.320411
# citympg           0.015940 -0.685751  -0.670909 -0.642704  -0.048640
# ...

# %%
plt.figure(figsize=(10,8))
correlations=Dataset.corr()
sns.heatmap(correlations,cmap="coolwarm",annot=True)
plt.show()
# Out:
# C:\Users\91930\AppData\Local\Temp\ipykernel_23304\995569078.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations=Dataset.corr()

# %%
Predict = "price"  # Assuming the correct column name is 'price' in lowercase
data = data[["symboling", "wheelbase", "carlength", "carwidth", "carheight", "curbweight", "compressionratio",
             "horsepower", "peakrpm", "citympg", "highwaympg", Predict]]

x = np.array(data.drop([Predict], 1))
y = np.array(data[Predict])
# Out:
# C:\Users\91930\AppData\Local\Temp\ipykernel_23304\1671600352.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(data.drop([Predict], 1))

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

model.fit(xtrain,ytrain)
predictions =model.predict(xtest)


from sklearn.metrics import mean_absolute_error
model.score(xtest,predictions)
# Out:
# 1.0

# %%
# The model gives 100% accuracy on the test Dataset
